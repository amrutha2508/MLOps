# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle
import seaborn as sns

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge

from sklearn.metrics import root_mean_squared_error

# %%
import pickle

# %%
import mlflow

mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("nyc-taxi-experiment")
# Out:
# <Experiment: artifact_location='/Users/amruthakaruturi/gitrepos/MLOps/mlruns/1', creation_time=1778078532580, experiment_id='1', last_update_time=1778078532580, lifecycle_stage='active', name='nyc-taxi-experiment', tags={}, trace_location=None, workspace='default'>

# %%
# Try using fastparquet if you have it installed
# df = pd.read_parquet('./data/green_tripdata_2021-01.parquet', engine='fastparquet')
def read_dataframe(filename):
    if filename.endswith('.csv'):
        df = pd.read_csv(filename)

        df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
        df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
    elif filename.endswith('.parquet'):
        df = pd.read_parquet(filename, engine="fastparquet")

    df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
    df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

    df = df[(df.duration >= 1) & (df.duration <= 60)]

    categorical = ['PULocationID', 'DOLocationID']
    df[categorical] = df[categorical].astype(str)
    
    return df

# %%
df_train = read_dataframe('./data/green_tripdata_2021-01.parquet')
df_val = read_dataframe('./data/green_tripdata_2021-02.parquet')

# %%
len(df_train), len(df_val)
# Out:
# (73908, 61921)

# %%
df_train['PU_DO'] = df_train['PULocationID'] + '_' + df_train['DOLocationID']
df_val['PU_DO'] = df_val['PULocationID'] + '_' + df_val['DOLocationID']

# %%
categorical = ['PU_DO'] #'PULocationID', 'DOLocationID']
numerical = ['trip_distance']

dv = DictVectorizer()

train_dicts = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dicts)

val_dicts = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dicts)

# %%
target = 'duration'
y_train = df_train[target].values
y_val = df_val[target].values

# %%
with mlflow.start_run():
    mlflow.set_tag("developer","ak")
    mlflow.set_tag("model","linear regression")
    mlflow.log_param("train-data-path","./data/green_tripdata_2021-01.parquet")
    mlflow.log_param("valid-data-path","./data/green_tripdata_2021-02.parquet")

    lr = LinearRegression()
    lr.fit(X_train, y_train)
    
    y_pred = lr.predict(X_val)
    
    rmse  = root_mean_squared_error(y_val, y_pred)
    mlflow.log_metric("rmse",rmse)

# %%
with mlflow.start_run():
    mlflow.set_tag("developer","ak")
    mlflow.set_tag("model", "lasso regression")
    mlflow.log_param("train-data-path","./data/green_tripdata_2021-01.parquet")
    mlflow.log_param("valid-data-path","./data/green_tripdata_2021-02.parquet")
    
    alpha = 0.01
    mlflow.log_param("alpha",alpha)
    lr = Lasso(alpha)
    lr.fit(X_train, y_train)
    y_pred = lr.predict(X_val)
    rmse = root_mean_squared_error(y_val, y_pred)
    mlflow.log_metric("rmse",rmse)

# %% [markdown]
# Hyperopt is a powerful Python library used for Bayesian Optimization. Unlike a simple Grid Search (which tries every combination) or Random Search (which picks at random), Hyperopt uses logic to "narrow in" on the best hyperparameters by learning from previous results.
#
# Component | Purpose
# 1. fmin,"The ""runner"" function. It minimizes your loss function over the hyperparameter space."
# 2. tpe,Tree-structured Parzen Estimator. This is the algorithm that decides which set of hyperparameters to try next based on past performance.
# 3. hp,"The ""Space"" builder. Contains functions like hp.uniform or hp.choice to define the range of your parameters."
# 4. STATUS_OK,"A mandatory signal sent back to Hyperopt to confirm a specific ""trial"" finished successfully."
# 5. Trials,"An object that stores the entire history (database) of every configuration tried, including the resulting loss."
# 6. scope,"Used to wrap functions (like scope.int) to ensure Hyperopt passes the correct data type (e.g., forcing a float to be an integer)."

# %%
# !pip install --upgrade setuptools
# Out:
# Requirement already satisfied: setuptools in ./env/lib/python3.14/site-packages (82.0.1)

# %%
import sys
from types import ModuleType

# --- STEP 1: PYTHON 3.14 COMPATIBILITY HACK ---
# This tricks hyperopt into thinking pkg_resources exists
pkg_mock = ModuleType("pkg_resources")
pkg_mock.get_distribution = lambda name: None
pkg_mock.resource_filename = lambda name, path: ""
sys.modules["pkg_resources"] = pkg_mock

# NOW do your imports
import xgboost as xgb
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials

# %%
# import xgboost as xgb

# from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

# %%
# !pip install setuptools
# Out:
# Requirement already satisfied: setuptools in ./env/lib/python3.14/site-packages (82.0.1)

# %%
my_trails =Trial

# %%
train = xgb.DMatrix(X_train, label=y_train)
valid = xgb.DMatrix(X_val,label=y_val)

# %%
def objective(params):
    with mlflow.start_run():
        mlflow.set_tag("model", "xgboost")
        mlflow.log_params(params)
        booster = xgb.train(
            params=params,
            dtrain = train,
            num_boost_round = 100, # caps the max no.of trees can be formed to predict previous trees residuals.
            evals = [(valid, "validation")],
            early_stopping_rounds = 5 # controls generation of the next trees
        )
        y_pred = booster.predict(valid)
        rmse = root_mean_squared_error(y_val, y_pred)
        mlflow.log_metric("rmse",rmse)
    return {"loss":rmse, "status":STATUS_OK}

# %%
search_space = {
    "max_depth": scope.int(hp.quniform("max_depth", 4,100, 1)),
    "learning_rate": hp.loguniform("learning_rate", -3, 0),
    "reg_alpha": hp.loguniform("reg_alpha", -5,-1),
    "reg_lambda": hp.loguniform("reg_lambda",-6,-1),
    "min_child_weight": hp.loguniform("min_child_weight", -1, 3),
    "objective": "reg:linear",
    "seed": 42
}

best_result = fmin(
    fn=objective,
    space = search_space,
    algo = tpe.suggest,
    max_evals= 50, # max no.of set of parameters to try
    trials = Trials(),
    # Stop if no improvement for 10 trials
    # early_stop_fn=early_stop.no_progress_loss(10)
)
# Out:
#   0%|                                                          | 0/50 [00:00<?, ?trial/s, best loss=?]
# /Users/amruthakaruturi/gitrepos/MLOps/env/lib/python3.14/site-packages/xgboost/callback.py:385: UserWarning: [16:18:18] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:277: reg:linear is now deprecated in favor of reg:squarederror.
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation-rmse:8
# [90]	validation-rmse:6.61402
# [91]	validation-rmse:6.61420
# [92]	validation-rmse:6.61417
# [93]	validation-rmse:6.61379
# [94]	validation-rmse:6.61394
# [95]	validation-rmse:6.61319
# [96]	validation-rmse:6.61301
# [97]	validation-rmse:6.61298
# [98]	validation-rmse:6.61320
# [99]	validation-rmse:6.61322
#   8%|██▋                              | 4/50 [00:23<04:39,  6.08s/trial, best loss: 6.346155158311665]
# /Users/amruthakaruturi/gitrepos/MLOps/env/lib/python3.14/site-packages/xgboost/callback.py:385: UserWarning: [16:18:42] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:277: reg:linear is now deprecated in favor of reg:squarederror.
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation-rmse:11.76493
# [1]	validation-rmse:11.34908
# [2]	validation-rmse:10.96359
# [3]	validation-rmse:10.60706
# [4]	validation-rmse:10.27729
# [5]	validation-rmse:9.97282
# [6]	validation-rmse:9.69168
# [7]	validation-rmse:9.43286
# [8]	validation-rmse:9.19454
# [9]	validation-rmse:8.97589
# [10]	validation-rmse:8.77547
# [11]	validation-rmse:8.59138
# [12]	validation-rmse:8.42265
# [13]	validation-rmse:8.26812
# [14]	validation-rmse:8.12703
# [15]	validation-rmse:7.99788
# [16]	validation-rmse:7.87964
# [17]	validation-rmse:7.77180
# [18]	validation-rmse:7.67353
# [19]	validation-rmse:7.58394
# [20]	validation-rmse:7.50262
# [21]	validation-rmse:7.42892
# [22]	validation-rmse:7.36124
# [23]	validation-rmse:7.29940
# [24]	validation-rmse:7.24324
# [25]	validation-rmse:7.19136
# [26]	validation-rmse:7.14400
# [27]	validation-rmse:7.10064
# [28]	validation-rmse:7.06126
# [29]	validation-rmse:7.02541
# [30]	validation-rmse:6.99293
# [31]	validation-rmse:6.96309
# [32]	validation-rmse:6.93540
# [33]	validation-rmse:6.91028
# [34]	validation-rmse:6.88669
# [35]	validation-rmse:6.86578
# [36]	validation-rmse:6.84574
# [37]	validation-rmse:6.82842
# [38]	validation-rmse:6.81138
# [39]	validation-rmse:6.79673
# [40]	validation-rmse:6.78245
# [41]	validation-rmse:6.76904
# [42]	validation-rmse:6.75763
# [43]	validation-rmse:6.74634
# [44]	validation-rmse:6.73600
# [45]	validation-rmse:6.72669
# [46]	validation-rmse:6.71788
# [47]	validation-rmse:6.70978
# [48]	validation-rmse:6.70234
# [49]	validation-rmse:6.69543
# [50]	validation-rmse:6.68869
# [51]	validation-rmse:6.68262
# [52]	validation-rmse:6.67708
# [53]	validation-rmse:6.67166
# [54]	validation-rmse:6.66671
# [55]	validation-rmse:6.66202
# [56]	validation-rmse:6.65784
# [57]	validation-rmse:6.65389
# [58]	validation-rmse:6.65009
# [59]	validation-rmse:6.64664
# [60]	validation-rmse:6.64339
# [61]	validation-rmse:6.64019
# [62]	validation-rmse:6.63756
# [63]	validation-rmse:6.63484
# [64]	validation-rmse:6.63216
# [65]	validation-rmse:6.62972
# [66]	validation-rmse:6.62728
# [67]	validation-rmse:6.62509
# [68]	validation-rmse:6.62286
# [69]	validation-rmse:6.62088
# [70]	validation-rmse:6.61901
# [71]	validation-rmse:6.61695
# [72]	validation-rmse:6.61528
# [73]	validation-rmse:6.61350
# [74]	validation-rmse:6.61202
# [75]	validation-rmse:6.61031
# [76]	validation-rmse:6.60879
# [77]	validation-rmse:6.60756
# [78]	validation-rmse:6.60560
# [79]	validation-rmse:6.60380
# [80]	validation-rmse:6.60199
# [81]	validation-rmse:6.60084
# [82]	validation-rmse:6.59922
# [83]	validation-rmse:6.59757
# [84]	validation-rmse:6.59646
# [85]	validation-rmse:6.59502
# [86]	validation-rmse:6.59344
# [87]	validation-rmse:6.59250
# ...
# [50]	validation-rmse:6.44107
# [51]	validation-rmse:6.44045
# [52]	validation-rmse:6.43960
# [53]	validation-rmse:6.43831
# [54]	validation-rmse:6.43746
# [55]	validation-rmse:6.43653
# [56]	validation-rmse:6.43634
# [57]	validation-rmse:6.43571
# [58]	validation-rmse:6.43509
# [59]	validation-rmse:6.43444
# [60]	validation-rmse:6.43265
# [61]	validation-rmse:6.43133
# [62]	validation-rmse:6.43081
# [63]	validation-rmse:6.43005
# [64]	validation-rmse:6.42933
# [65]	validation-rmse:6.42858
# [66]	validation-rmse:6.42775
# [67]	validation-rmse:6.42731
# [68]	validation-rmse:6.42686
# [69]	validation-rmse:6.42686
# [70]	validation-rmse:6.42625
# [71]	validation-rmse:6.42548
# [72]	validation-rmse:6.42495
# [73]	validation-rmse:6.42433
# [74]	validation-rmse:6.42395
# [75]	validation-rmse:6.42289
# [76]	validation-rmse:6.42260
# [77]	validation-rmse:6.42243
# [78]	validation-rmse:6.42216
# [79]	validation-rmse:6.42245
# [80]	validation-rmse:6.42227
# [81]	validation-rmse:6.42216
# [82]	validation-rmse:6.42183
# [83]	validation-rmse:6.42155
# [84]	validation-rmse:6.42078
# [85]	validation-rmse:6.42005
# [86]	validation-rmse:6.41962
# [87]	validation-rmse:6.41924
# [88]	validation-rmse:6.41852
# [89]	validation-rmse:6.41835
# [90]	validation-rmse:6.41813
# [91]	validation-rmse:6.41777
# [92]	validation-rmse:6.41732
# [93]	validation-rmse:6.41673
# [94]	validation-rmse:6.41383
# [95]	validation-rmse:6.41392
# [96]	validation-rmse:6.41310
# [97]	validation-rmse:6.41295
# [98]	validation-rmse:6.41275
# [99]	validation-rmse:6.41272
#  98%|███████████████████████████████▎| 49/50 [06:15<00:08,  8.29s/trial, best loss: 6.329028184206968]
# /Users/amruthakaruturi/gitrepos/MLOps/env/lib/python3.14/site-packages/xgboost/callback.py:385: UserWarning: [16:24:34] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:277: reg:linear is now deprecated in favor of reg:squarederror.
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation-rmse:10.27961
# [1]	validation-rmse:8.98135
# [2]	validation-rmse:8.13959
# [3]	validation-rmse:7.58610
# [4]	validation-rmse:7.23701
# [5]	validation-rmse:7.01395
# [6]	validation-rmse:6.86836
# [7]	validation-rmse:6.77303
# [8]	validation-rmse:6.70882
# [9]	validation-rmse:6.66614
# [10]	validation-rmse:6.63257
# [11]	validation-rmse:6.61128
# [12]	validation-rmse:6.59525
# [13]	validation-rmse:6.58310
# [14]	validation-rmse:6.57460
# [15]	validation-rmse:6.56721
# [16]	validation-rmse:6.56055
# [17]	validation-rmse:6.55539
# [18]	validation-rmse:6.55188
# [19]	validation-rmse:6.54992
# [20]	validation-rmse:6.54646
# [21]	validation-rmse:6.54373
# [22]	validation-rmse:6.54063
# [23]	validation-rmse:6.53930
# [24]	validation-rmse:6.53634
# [25]	validation-rmse:6.53262
# [26]	validation-rmse:6.53110
# [27]	validation-rmse:6.52862
# [28]	validation-rmse:6.52641
# [29]	validation-rmse:6.52423
# [30]	validation-rmse:6.52286
# [31]	validation-rmse:6.52185
# [32]	validation-rmse:6.52051
# [33]	validation-rmse:6.52010
# [34]	validation-rmse:6.51879
# [35]	validation-rmse:6.51698
# [36]	validation-rmse:6.51517
# [37]	validation-rmse:6.51382
# [38]	validation-rmse:6.51305
# [39]	validation-rmse:6.51132
# [40]	validation-rmse:6.51044
# [41]	validation-rmse:6.50773
# [42]	validation-rmse:6.50622
# [43]	validation-rmse:6.50435
# [44]	validation-rmse:6.50264
# [45]	validation-rmse:6.50198
# [46]	validation-rmse:6.50101
# [47]	validation-rmse:6.49891
# [48]	validation-rmse:6.49742
# [49]	validation-rmse:6.49626
# [50]	validation-rmse:6.49561
# [51]	validation-rmse:6.49372
# [52]	validation-rmse:6.49293
# [53]	validation-rmse:6.49097
# [54]	validation-rmse:6.49032
# [55]	validation-rmse:6.48997
# [56]	validation-rmse:6.48708
# [57]	validation-rmse:6.48594
# [58]	validation-rmse:6.48474
# [59]	validation-rmse:6.48408
# [60]	validation-rmse:6.48331
# [61]	validation-rmse:6.48276
# [62]	validation-rmse:6.48208
# [63]	validation-rmse:6.48070
# [64]	validation-rmse:6.48014
# [65]	validation-rmse:6.47923
# [66]	validation-rmse:6.47811
# [67]	validation-rmse:6.47667
# [68]	validation-rmse:6.47550
# [69]	validation-rmse:6.47482
# [70]	validation-rmse:6.47410
# [71]	validation-rmse:6.47225
# [72]	validation-rmse:6.47093
# [73]	validation-rmse:6.47043
# [74]	validation-rmse:6.46989
# [75]	validation-rmse:6.46855
# [76]	validation-rmse:6.46776
# [77]	validation-rmse:6.46703
# [78]	validation-rmse:6.46640
# [79]	validation-rmse:6.46554
# [80]	validation-rmse:6.46475
# [81]	validation-rmse:6.46447
# [82]	validation-rmse:6.46309
# [83]	validation-rmse:6.46227
# [84]	validation-rmse:6.46137
# [85]	validation-rmse:6.46093
# [86]	validation-rmse:6.46054
# [87]	validation-rmse:6.45940
# [88]	validation-rmse:6.45731
# [89]	validation-rmse:6.45684
# [90]	validation-rmse:6.45591
# [91]	validation-rmse:6.45600
# [92]	validation-rmse:6.45437
# [93]	validation-rmse:6.45403
# [94]	validation-rmse:6.45347
# [95]	validation-rmse:6.45349
# [96]	validation-rmse:6.45282
# [97]	validation-rmse:6.45221
# [98]	validation-rmse:6.45197
# [99]	validation-rmse:6.45154
# 100%|████████████████████████████████| 50/50 [06:25<00:00,  7.71s/trial, best loss: 6.329028184206968]
